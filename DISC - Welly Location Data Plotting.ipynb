# %% [markdown]
# ### Importing Libraries and Data

# %%
from welly import Location
from welly import Well
import pandas as pd
# Out:
# C:\Users\peter\Anaconda3\envs\t22_setup\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data = Well.from_las('DISC-Sample_Las_file02.LAS')

# %%
data
# Out:
# Well(uwi: '', name: 'Sample well 2', 25 curves: ['TVD', 'ROP_AVG', 'GRAFM', 'RPCHM', 'RACLM', 'TCDM', 'ACTECDM', 'NPLFM', 'NPLM', 'NPSM', 'NPSFM', 'NNBM', 'NFBM', 'NPIM', 'BDCFM', 'BDCM', 'DPEM', 'DRHM', 'DRHFM', 'GRCFM', 'GRAM', 'GRCM', 'BDIM', 'DTHM', 'SVHM'])

# %%
data.data
# Out:
# {'TVD': Curve(mnemonic=TVD, units=ft, start=11000.0000, stop=14201.5000, step=0.2500, count=[12437]),
#  'ROP_AVG': Curve(mnemonic=ROP_AVG, units=ft/hr, start=11000.0000, stop=14201.5000, step=0.2500, count=[12437]),
#  'GRAFM': Curve(mnemonic=GRAFM, units=API, start=11000.0000, stop=14201.5000, step=0.2500, count=[12635]),
#  'RPCHM': Curve(mnemonic=RPCHM, units=ohm.m, start=11000.0000, stop=14201.5000, step=0.2500, count=[12658]),
#  'RACLM': Curve(mnemonic=RACLM, units=ohm.m, start=11000.0000, stop=14201.5000, step=0.2500, count=[12658]),
#  'TCDM': Curve(mnemonic=TCDM, units=degF, start=11000.0000, stop=14201.5000, step=0.2500, count=[12655]),
#  'ACTECDM': Curve(mnemonic=ACTECDM, units=ppg, start=11000.0000, stop=14201.5000, step=0.2500, count=[12659]),
#  'NPLFM': Curve(mnemonic=NPLFM, units=pu, start=11000.0000, stop=14201.5000, step=0.2500, count=[12519]),
#  'NPLM': Curve(mnemonic=NPLM, units=pu, start=11000.0000, stop=14201.5000, step=0.2500, count=[12519]),
#  'NPSM': Curve(mnemonic=NPSM, units=pu, start=11000.0000, stop=14201.5000, step=0.2500, count=[12519]),
#  'NPSFM': Curve(mnemonic=NPSFM, units=pu, start=11000.0000, stop=14201.5000, step=0.2500, count=[12519]),
#  'NNBM': Curve(mnemonic=NNBM, units=cps, start=11000.0000, stop=14201.5000, step=0.2500, count=[12519]),
#  'NFBM': Curve(mnemonic=NFBM, units=cps, start=11000.0000, stop=14201.5000, step=0.2500, count=[12519]),
#  'NPIM': Curve(mnemonic=NPIM, units=unitless, start=11000.0000, stop=14201.5000, step=0.2500, count=[12519]),
#  'BDCFM': Curve(mnemonic=BDCFM, units=g/cc, start=11000.0000, stop=14201.5000, step=0.2500, count=[12553]),
#  'BDCM': Curve(mnemonic=BDCM, units=g/cc, start=11000.0000, stop=14201.5000, step=0.2500, count=[12552]),
#  'DPEM': Curve(mnemonic=DPEM, units=unitless, start=11000.0000, stop=14201.5000, step=0.2500, count=[12552]),
#  'DRHM': Curve(mnemonic=DRHM, units=g/cc, start=11000.0000, stop=14201.5000, step=0.2500, count=[12552]),
#  'DRHFM': Curve(mnemonic=DRHFM, units=g/cc, start=11000.0000, stop=14201.5000, step=0.2500, count=[12553]),
#  'GRCFM': Curve(mnemonic=GRCFM, units=API, start=11000.0000, stop=14201.5000, step=0.2500, count=[12657]),
#  'GRAM': Curve(mnemonic=GRAM, units=API, start=11000.0000, stop=14201.5000, step=0.2500, count=[12659]),
#  'GRCM': Curve(mnemonic=GRCM, units=API, start=11000.0000, stop=14201.5000, step=0.2500, count=[12659]),
#  'BDIM': Curve(mnemonic=BDIM, units=unitless, start=11000.0000, stop=14201.5000, step=0.2500, count=[12552]),
#  'DTHM': Curve(mnemonic=DTHM, units=usec/ft, start=11000.0000, stop=14201.5000, step=0.2500, count=[12309]),
#  'SVHM': Curve(mnemonic=SVHM, units=unitless, start=11000.0000, stop=14201.5000, step=0.2500, count=[12309])}

# %%
data.plot(extents='curves')

# %% [markdown]
# ### Importing Survey Data

# %% [markdown]
# Survey data is commonly measured at irregular intervals during the drilling process. It gives a snapshot of the measured depth, inclination and azimuth at the time of the survey. From this, we can calculated the True Vertical Depth, x-offset and y-offset from the origin point of the well.

# %%
survey = pd.read_excel('DISC_sample_survey_data01.xlsx')

# %%
survey
# Out:
#           MD  Inclination  Azimuth       TVD  TVD from Fld Ref    North  \
# 0       0.00        0.000  225.840      0.00            -82.00   124.64
# 1    4653.00        0.000    0.000   4653.00           4571.00   124.64
# 2    4735.00        0.000    0.000   4735.00           4653.00   124.64
# 3    5121.41        1.470  225.840   5121.37           5039.37   121.19
# 4    5247.13        1.510  220.170   5247.05           5165.05   118.80
# ..       ...          ...      ...       ...               ...      ...
# 70  13802.86       19.090  173.980  13159.34          13077.34 -2459.97
# 71  13931.13       19.060  174.720  13280.57          13198.57 -2501.69
# 72  14056.62       18.890  175.220  13399.24          13317.24 -2542.33
# 73  14152.29       19.000  173.930  13489.73          13407.73 -2573.25
# 74  14201.44       18.987  173.923  13536.20          13454.20 -2589.16
#
#       East          Grid East  Grid North       Latitude      Longitude   DLS  \
# 0  -267.93  783020.0000000000   384521.00  3°28'31.394"N  5°32'50.083"E  0.00
# 1  -267.93  783020.0000000000   384521.00  3°28'31.394"N  5°32'50.083"E  0.00
# 2  -267.93  783020.0000000000   384521.00  3°28'31.394"N  5°32'50.083"E  0.00
# 3  -271.48  783018.9200000000   384519.95  3°28'31.360"N  5°32'50.047"E  0.38
# 4  -273.71  783018.2400000000   384519.22  3°28'31.336"N  5°32'50.025"E  0.12
# ..     ...                ...         ...            ...            ...   ...
# 70  504.14  783255.4700000000   383732.74  3°28'05.726"N  5°32'57.638"E  0.29
# 71  508.27  783256.7300000000   383720.02  3°28'05.312"N  5°32'57.678"E  0.19
# 72  511.85  783257.8199999999   383707.62  3°28'04.909"N  5°32'57.712"E  0.19
# 73  514.79  783258.7100000000   383698.20  3°28'04.602"N  5°32'57.740"E  0.45
# 74  516.48  783259.2300000000   383693.34  3°28'04.444"N  5°32'57.756"E  0.03
#
#     Toolface  Build Rate  Turn Rate  Vert Sect          Comments
# 0       0.00        0.00       0.00      -8.99
# 1       0.00        0.00       0.00      -8.99           mudline
# 2    -134.16        0.00       0.00      -8.99
# 3     -77.67        0.38       0.00      -6.63
# 4     150.69        0.03      -4.51      -4.94
# ..       ...         ...        ...        ...               ...
# 70     97.42        0.08      -0.84    2688.19
# 71    136.51       -0.02       0.58    2729.46
# 72    -75.89       -0.14       0.40    2769.54
# 73   -169.75        0.11      -1.35    2800.09
# 74      0.00       -0.03      -0.01    2815.86   PROJECTED TO TD
#
# [75 rows x 17 columns]

# %% [markdown]
# Welly requires the survey data to contain MD - measured depth, INC - inclination and AZI - azimuth. This allows the library to calculate the TVD, X-offset and Y-offset.
#
# We can subset the data by using the square brackets and passing in a list of the column names.

# %%
survey_subset = survey[['MD', 'Inclination', 'Azimuth']]

# %%
survey_subset
# Out:
#           MD  Inclination  Azimuth
# 0       0.00        0.000  225.840
# 1    4653.00        0.000    0.000
# 2    4735.00        0.000    0.000
# 3    5121.41        1.470  225.840
# 4    5247.13        1.510  220.170
# ..       ...          ...      ...
# 70  13802.86       19.090  173.980
# 71  13931.13       19.060  174.720
# 72  14056.62       18.890  175.220
# 73  14152.29       19.000  173.930
# 74  14201.44       18.987  173.923
#
# [75 rows x 3 columns]

# %% [markdown]
# ### Adding Survey Data to Welly Well

# %% [markdown]
# After the survey data has been loaded from a CSV or Excel file, we need to calculate our location parameters. By default welly is set to calculate these using the minimum curvature method, which is the most common and most accurate method for this purpose. More information can be found at https://petrowiki.spe.org/Calculation_methods_for_directional_survey

# %%
#Add deviation data to a well
data.location.add_deviation(survey_subset.values)

# %% [markdown]
# Now that the survey data has been loaded in, and attached to the well, we can call upon data.location.position to view the data.
#
# The data is formatted as: X-offset, Y-offset and TVD.

# %%
data.location.position[:5]
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  4.65300000e+03],
#        [ 0.00000000e+00,  0.00000000e+00,  4.73500000e+03],
#        [-3.55589465e+00, -3.45312962e+00,  5.12136761e+03],
#        [-5.78126269e+00, -5.84230842e+00,  5.24704517e+03]])

# %% [markdown]
# We can extract each of the location parameters into variables by slicing up the array. This is done using square brakcets and selecting all rows using the colon (:) followed by the column within the array.

# %%
x_loc = data.location.position[:,0]
y_loc = data.location.position[:,1]
z_loc = data.location.position[:,2]

# %%
z_loc
# Out:
# array([    0.        ,  4653.        ,  4735.        ,  5121.36760914,
#         5247.04516723,  5378.90116358,  5515.67366714,  5634.00873757,
#         5762.12798071,  5893.37144821,  6025.95514038,  6149.2393471 ,
#         6284.23030416,  6407.36924371,  6484.78312062,  6617.72763344,
#         6733.24976369,  6875.68668119,  7003.86105426,  7223.25037849,
#         7285.86191567,  7412.66590455,  7532.72803994,  7656.26711755,
#         7793.39421102,  7908.81706694,  8045.5165428 ,  8153.82798882,
#         8287.94826117,  8401.43183343,  8535.98720841,  8651.1012064 ,
#         8773.65627329,  8876.42714563,  8987.95641249,  9107.87128349,
#         9213.31446528,  9317.78833336,  9415.22919951,  9529.51236971,
#         9632.64573156,  9739.32812737,  9845.67636185,  9947.96287831,
#        10052.2363794 , 10159.11033259, 10264.96543233, 10373.41416935,
#        10479.74426661, 10679.66277342, 10787.66285322, 10889.51481086,
#        10999.82796272, 11113.00049125, 11231.30479502, 11340.56445648,
#        11463.97151887, 11584.05895853, 11708.3382073 , 11830.1312333 ,
#        11952.28429992, 12067.22525504, 12189.21503157, 12309.58469795,
#        12434.25622076, 12554.72334001, 12670.3320855 , 12792.94074696,
#        12916.54151913, 13039.24432331, 13159.34390816, 13280.57098601,
#        13399.24196346, 13489.72997197, 13536.2040249 ])

# %%
data.location.tvd
# Out:
# array([    0.        ,  4653.        ,  4735.        ,  5121.36760914,
#         5247.04516723,  5378.90116358,  5515.67366714,  5634.00873757,
#         5762.12798071,  5893.37144821,  6025.95514038,  6149.2393471 ,
#         6284.23030416,  6407.36924371,  6484.78312062,  6617.72763344,
#         6733.24976369,  6875.68668119,  7003.86105426,  7223.25037849,
#         7285.86191567,  7412.66590455,  7532.72803994,  7656.26711755,
#         7793.39421102,  7908.81706694,  8045.5165428 ,  8153.82798882,
#         8287.94826117,  8401.43183343,  8535.98720841,  8651.1012064 ,
#         8773.65627329,  8876.42714563,  8987.95641249,  9107.87128349,
#         9213.31446528,  9317.78833336,  9415.22919951,  9529.51236971,
#         9632.64573156,  9739.32812737,  9845.67636185,  9947.96287831,
#        10052.2363794 , 10159.11033259, 10264.96543233, 10373.41416935,
#        10479.74426661, 10679.66277342, 10787.66285322, 10889.51481086,
#        10999.82796272, 11113.00049125, 11231.30479502, 11340.56445648,
#        11463.97151887, 11584.05895853, 11708.3382073 , 11830.1312333 ,
#        11952.28429992, 12067.22525504, 12189.21503157, 12309.58469795,
#        12434.25622076, 12554.72334001, 12670.3320855 , 12792.94074696,
#        12916.54151913, 13039.24432331, 13159.34390816, 13280.57098601,
#        13399.24196346, 13489.72997197, 13536.2040249 ])

# %% [markdown]
# ### Creating Location Plots

# %% [markdown]
# To understand the position of the well, we can call upon three plots.
# The first plots the x and y offset and gives us a top down view / map view of the well path.
# The next two plots show us how the well changes in the x location versus TVD and the y location versus TVD.

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(15,5))
ax1 = plt.subplot2grid(shape=(1,3), loc=(0,0))
ax2 = plt.subplot2grid(shape=(1,3), loc=(0,1))
ax3 = plt.subplot2grid(shape=(1,3), loc=(0,2))

ax1.plot(x_loc, y_loc, lw=3)
ax1.set_title('X Location vs Y Location')

ax2.plot(x_loc, z_loc, lw=3)
ax2.set_title('X Location vs TVD')

ax3.plot(y_loc, z_loc, lw=3)
ax3.set_title('Y Location vs TVD')
# Out:
# Text(0.5, 1.0, 'Y Location vs TVD')

# %% [markdown]
# ### Add Markers for Start of the Well & End of the Well

# %% [markdown]
# We can add a couple of markers to our plot to show the starting location (black square) and the end location (red star) of the well.
# Additionally, for the plots with TVD, we can understand them better if we invert the y-axis using ax.invert_yaxis()

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax1 = plt.subplot2grid(shape=(1,3), loc=(0,0))
ax2 = plt.subplot2grid(shape=(1,3), loc=(0,1))
ax3 = plt.subplot2grid(shape=(1,3), loc=(0,2))

ax1.plot(x_loc, y_loc, lw=3)
ax1.plot(x_loc[0], y_loc[0], marker='s', color='black', ms=8)
ax1.plot(x_loc[-1], y_loc[-1], marker='*', color='red', ms=8)
ax1.set_title('X Location vs Y Location')

ax2.plot(x_loc, z_loc, lw=3)
ax2.plot(x_loc[0], z_loc[0], marker='s', color='black', ms=8)
ax2.plot(x_loc[-1], z_loc[-1], marker='*', color='red', ms=8)
ax2.invert_yaxis()
ax2.set_title('X Location vs TVD')

ax3.plot(y_loc, z_loc, lw=3)
ax3.plot(y_loc[0], z_loc[0], marker='s', color='black', ms=8)
ax3.plot(y_loc[-1], z_loc[-1], marker='*', color='red', ms=8)
ax3.invert_yaxis()
ax3.set_title('Y Location vs TVD')
# Out:
# Text(0.5, 1.0, 'Y Location vs TVD')

# %% [markdown]
# ### Create 3D Plot of Well Path

# %% [markdown]
# Rather than viewing the data in two dimensions, we can view it in three dimensions using matplotlib. But first we have to calculate continuous data. This is done by using location.trajectory(). Here we can provide a datum, i.e the UTM co-ordinates of the well location at surface, and a vertical offset.

# %%
# Create a trajectory of regularly sampled points
location_data = data.location.trajectory(datum=[783023.00, 384519.00, 47.5], elev=False)

# %%
xs = location_data[:,0]
ys = location_data[:,1]
zs = location_data[:,2]

# %%
zs
# Out:
# array([   47.49996169,    61.71960883,    75.93922097,    90.1587982 ,
#          104.37834062,   118.59784829,   132.81732133,   147.0367598 ,
#          161.2561638 ,   175.47553343,   189.69486875,   203.91416987,
#          218.13343688,   232.35266985,   246.57186888,   260.79103405,
#          275.01016546,   289.22926319,   303.44832732,   317.66735796,
#          331.88635517,   346.10531906,   360.32424971,   374.54314721,
#          388.76201165,   402.9808431 ,   417.19964168,   431.41840744,
#          445.6371405 ,   459.85584094,   474.07450883,   488.29314428,
#          502.51174737,   516.73031818,   530.94885681,   545.16736334,
#          559.38583786,   573.60428046,   587.82269123,   602.04107025,
#          616.25941761,   630.4777334 ,   644.69601771,   658.91427063,
#          673.13249224,   687.35068263,   701.56884189,   715.78697011,
#          730.00506738,   744.22313377,   758.44116939,   772.65917432,
#          786.87714864,   801.09509245,   815.31300583,   829.53088887,
#          843.74874166,   857.96656428,   872.18435683,   886.40211939,
#          900.61985206,   914.8375549 ,   929.05522803,   943.27287152,
#          957.49048545,   971.70806993,   985.92562504,  1000.14315086,
#         1014.36064748,  1028.57811499,  1042.79555349,  1057.01296305,
#         1071.23034376,  1085.44769571,  1099.665019  ,  1113.8823137 ,
#         1128.09957991,  1142.31681772,  1156.5340272 ,  1170.75120846,
#         1184.96836157,  1199.18548663,  1213.40258372,  1227.61965293,
#         1241.83669435,  1256.05370807,  1270.27069417,  1284.48765274,
#         1298.70458388,  1312.92148766,  1327.13836418,  1341.35521353,
#         1355.57203578,  1369.78883104,  1384.00559938,  1398.2223409 ,
#         1412.43905568,  1426.65574382,  1440.87240539,  1455.08904049,
#         1469.30564921,  1483.52223163,  1497.73878784,  1511.95531793,
#         1526.17182198,  1540.38830009,  1554.60475234,  1568.82117882,
#         1583.03757962,  1597.25395483,  1611.47030453,  1625.68662881,
#         1639.90292777,  1654.11920147,  1668.33545003,  1682.55167352,
#         1696.76787203,  1710.98404564,  1725.20019446,  1739.41631856,
#         1753.63241803,  1767.84849297,  1782.06454345,  1796.28056957,
#         1810.49657141,  1824.71254906,  1838.92850262,  1853.14443216,
#         1867.36033778,  1881.57621956,  1895.7920776 ,  1910.00791197,
#         1924.22372277,  1938.43951008,  1952.655274  ,  1966.87101461,
#         1981.086732  ,  1995.30242626,  2009.51809747,  2023.73374572,
#         2037.9493711 ,  2052.1649737 ,  2066.38055361,  2080.59611091,
#         2094.81164569,  2109.02715805,  2123.24264806,  2137.45811581,
#        11607.71635226, 11621.09409504, 11634.48453434, 11647.88680827,
#        11661.30005496, 11674.72341253, 11688.15601913, 11701.59701286,
#        11715.04553186, 11728.50071426, 11741.96169818, 11755.42762174,
#        11768.89762308, 11782.37084032, 11795.84641159, 11809.32347501,
#        11822.80116871, 11836.27863082, 11849.75499947, 11863.22941277,
#        11876.70100886, 11890.16907197, 11903.6335892 , 11917.09475878,
#        11930.552779  , 11944.00784811, 11957.4601644 , 11970.90992614,
#        11984.35733159, 11997.80257904, 12011.24586675, 12024.687393  ,
#        12038.12735605, 12051.56595418, 12065.00338567, 12078.43984878,
#        12091.87554179, 12105.31066297, 12118.74540988, 12132.17991925,
#        12145.6142211 , 12159.04833464, 12172.48227909, 12185.91607367,
#        12199.34973759, 12212.78329008, 12226.21675034, 12239.65013761,
#        12253.08347109, 12266.51677   , 12279.95005356, 12293.38334098,
#        12306.81665149, 12320.25000431, 12333.68341864, 12347.11691371,
#        12360.55050874, 12373.98422293, 12387.41807552, 12400.85208571,
#        12414.28627273, 12427.72065578, 12441.1552541 , 12454.59008689,
#        12468.02517338, 12481.46053278, 12494.8961843 , 12508.33214718,
#        12521.76844061, 12535.20508383, 12548.64209605, 12562.07949648,
#        12575.51730434, 12588.95553886, 12602.39421924, 12615.83335863,
#        12629.2729469 , 12642.71296836, 12656.15340732, 12669.5942481 ,
#        12683.03547502, 12696.47707238, 12709.9190245 , 12723.3613157 ,
#        12736.80393028, 12750.24685256, 12763.69006685, 12777.13355746,
#        12790.57730872, 12804.02130493, 12817.4655304 , 12830.90996946,
#        12844.35460641, 12857.79942556, 12871.24441123, 12884.68954774,
#        12898.13481939, 12911.58021051, 12925.02570539, 12938.47128836,
#        12951.91694374, 12965.36265582, 12978.80840893, 12992.25418738,
#        13005.69997549, 13019.14575756, 13032.59151791, 13046.03724085,
#        13059.48291071, 13072.92851178, 13086.37402838, 13099.81944484,
#        13113.26474545, 13126.70991453, 13140.15493641, 13153.59979538,
#        13167.04447577, 13180.48896188, 13193.93323804, 13207.37728855,
#        13220.82109772, 13234.26464988, 13247.70792933, 13261.15092039,
#        13274.59360737, 13288.03597458, 13301.47800634, 13314.91968696,
#        13328.36100076, 13341.80193204, 13355.24246512, 13368.68258432,
#        13382.12227395, 13395.56151831, 13409.00030174, 13422.43860853,
#        13435.876423  , 13449.31372946, 13462.75051223, 13476.18675563,
#        13489.62244396, 13503.05756154, 13516.49209267, 13529.92602169,
#        13543.35933289, 13556.79201059, 13570.22403911, 13583.65540276])

# %%
plt.plot(xs, ys)
plt.xlabel('X Location')
plt.ylabel('Y Location')
plt.ticklabel_format(style='plain')
plt.grid()

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
# Enable 3D Ploting
# %matplotlib widget

# %%
fig = plt.figure(figsize=(8, 8))

ax = plt.axes(projection='3d')
ax.plot3D(xs, ys, zs, lw=10)
ax.set_zlim(13500, 0)

ax.set_xlabel('X Location')
ax.set_ylabel('Y Location')
ax.set_zlabel('TVD')

plt.ticklabel_format(style='plain')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
